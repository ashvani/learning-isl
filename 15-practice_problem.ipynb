# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Dataset: https://www.openml.org/search?type=data&sort=version&status=any&order=asc&exact_name=letter&id=6

# %%
import joblib
X, y = joblib.load('practice_data')

# %%
X.shape
# Out:
# (20000, 16)

# %%
y = y['lettr']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25)

# %%
parameters = {'C': [10, 100, 1000],
              'gamma': [0.01, 0.1, 1, 10]
             }
clf = GridSearchCV(SVC(), parameters, verbose = 5)
clf = clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.961 total time=   3.8s
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.971 total time=   3.5s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.966 total time=   4.3s
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.965 total time=   2.9s
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.970 total time=   3.8s
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.966 total time=  16.6s
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.969 total time=  14.3s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.972 total time=  14.3s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.967 total time=  17.8s
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.973 total time=  14.6s
# [CV 1/5] END .....................C=10, gamma=1;, score=0.483 total time=  22.6s
# ...

# %%
parameters = {'C': [1, 5, 10],
              'gamma': [0.001, 0.01, 0.1]
             }
clf = GridSearchCV(SVC(), parameters, verbose = 5)
clf = clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.797 total time=  12.0s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.804 total time=  12.0s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.794 total time=  11.8s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.800 total time=  11.9s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.808 total time=  11.7s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.926 total time=   6.0s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.939 total time=   4.5s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.925 total time=   4.4s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.926 total time=   3.6s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.933 total time=   4.5s
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.963 total time=  14.6s
# ...

# %%
print(clf.best_estimator_)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# SVC(C=10, gamma=0.1)
# {'C': 10, 'gamma': 0.1}
# 0.9693333333333334

# %%
model = SVC(C=10, gamma=0.1)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9744
