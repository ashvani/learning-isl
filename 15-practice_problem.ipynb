# %%
import pandas as pd
import joblib

# %%
X, y = joblib.load('practice_data_train')
X_test = joblib.load('practice_data_test')
print(X.head())
print(y.head())
print(X_test.head())
# Out:
#    C1  C2  C3  C4  C5  C6  C7  C8  C9  C10  C11  C12  C13  C14  C15  C16  \
# 0   6  11   8   8   9   5   8   3   4    8    8    9    7    9    5    4
# 1   2   1   3   1   2   7   7   4   5    7    6    6    1    8    5    9
# 2   6   9   7  11   9   8   4   8   4    6    5    7    5    8    7   11
# 3   5  10   5   7   3   3  11   3   4   10   12    8    2   10    1    8
# 4   5   8   5   9   5   8   6   7   2    8    7   12    3    8    6    7
#
#                                      id
# 0  277b0762-060f-44aa-94b8-706c5f0080df
# 1  b25b7da6-8849-454d-937a-a4f12cc5d04b
# 2  1226ecbd-5a66-4938-9281-6a5f710240c7
# 3  7fa1c538-2e1b-4fe8-9614-29f85c2a9c9a
# 4  14fc1606-e181-4d19-a40a-ab83acf6aada
#   lettr                                    id
# 0     N  277b0762-060f-44aa-94b8-706c5f0080df
# 1     B  b25b7da6-8849-454d-937a-a4f12cc5d04b
# 2     Q  1226ecbd-5a66-4938-9281-6a5f710240c7
# 3     V  7fa1c538-2e1b-4fe8-9614-29f85c2a9c9a
# 4     Q  14fc1606-e181-4d19-a40a-ab83acf6aada
# ...
