# %%
import pandas as pd

# %%
df = pd.read_csv(r'spam_dataset.csv')
df.head()
# Out:
#   Label                                            Message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Steps to follow
# 1. Is this a classification/regression problem?
# 2. Check the distribution of label
# 3. How do we create features from a verbatim column?
#    1. Use Tf-Idf vectorizer to create features
#
# 4. Divide the dataset in 2 parts; Train and a Test set
#
# 5. Try different models and select best set of parameters by hyperperameter tunning
#    1. Logistic Regression
#    2. Naive Bayes
#    3. KNN
#    4. Decision Tree
#    5. Random Forest
#    6. SVM
#
# 6. Serialize and deserialize the model for production/deployment

# %%
# Out:
# Label
# ham     0.865985
# spam    0.134015
# Name: proportion, dtype: float64
